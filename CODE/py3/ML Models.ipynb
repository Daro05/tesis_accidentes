# %%
#importamos todos los paquetes necesarios
import os
import numpy as np 
from numpy import loadtxt
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

from keras.models import Sequential
from keras.layers import Dense, Dropout

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

from math import pi
from scipy.cluster.hierarchy import dendrogram, ward, single, complete, average, linkage, fcluster
from scipy.spatial.distance import pdist

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from scipy import stats
from scipy.cluster import hierarchy

from tslearn.clustering import TimeSeriesKMeans
from tslearn.clustering import KShape




from imblearn.over_sampling import SMOTE

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score,roc_auc_score, accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.tree import export_graphviz
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import roc_curve
from IPython.display import Image  
from sklearn import tree
from sklearn.svm import SVC
from sklearn.metrics import make_scorer
#import pydotplus
pd.set_option('display.max_columns', None)

# %matplotlib notebook
# %matplotlib inline

# %%
train100 = pd.read_csv('/Users/daniel.rodriguez/Documents/ACC/ACC_PROOF/ACC1/final_datasets/train100_fin.csv', sep = ',',index_col = False)
test100 = pd.read_csv('/Users/daniel.rodriguez/Documents/ACC/ACC_PROOF/ACC1/final_datasets/test100_fin.csv', sep = ',',index_col = False)

# %%
X, y = train100[[#'Unnamed: 0', 
                 #'X', 
                 #'Y', 
                 'attraction', 
                 'bank', 
                 'bar', 
                 'cetram', 
                 'cinema', 
                 'college', 
                 'crossing', 
                 'cruce_peligroso', 
                 'hospital',  
                 'hotel', 
                 'interseccion', 
                 'kindergarten', 
                 'mall', 
                 'metro', 
                 'metrobus', 
                 'mini_roundabout', 
                 'museum', 
                 'nightclub', 
                 'park', 
                 'pub', 
                 'restaurant', 
                 'rtp', 
                 'school', 
                 'speed_camera', 
                 'supermarket', 
                 'theatre', 
                 'traffic_signals', 
                 'trolebus', 
                 'turning_circle', 
                 'university',
                 
                 'bar_300',
                 'crossing_300',
                 'hospital_300',
                 'hotel_300',
                 'metro_300',
                 'nightclub_300',
                 'restaurant_300', 
                 'rtp_300',
                 'school_300',
                 'speed_camera_300',
                 'traffic_signals_300',
                 
                 'ACC_C_LESION_100',
                 'ACC_FATAL_100', 
                 'ACC_PRENSADO_100', 
                 'ACC_S_LESION_100',
                 'ATROPELLADO_100', 
                 'ATROPELLADO_FATAL_100',
                 'FERROVIARIO_100',
                 'MOTOCICLISTA_100',
                 'OTROS_100',
                 'PER_ATRAPADO_DESBARRANCADO_100',
                 'VEH_ATRAPADO_100',
                 'VEH_DESBARRANCADO_100', 
                 'VOLCADURA_100',

                 'ACC_C_LESION_200', 
                 'ACC_FATAL_200',
                 'ACC_PRENSADO_200', 
                 'ACC_S_LESION_200', 
                 'ATROPELLADO_200',
                 'ATROPELLADO_FATAL_200', 
                 'FERROVIARIO_200', 
                 'MOTOCICLISTA_200', 
                 'OTROS_200', 
                 'PER_ATRAPADO_DESBARRANCADO_200', 
                 'VEH_ATRAPADO_200', 
                 'VEH_DESBARRANCADO_200',
                 'VOLCADURA_200']],train100[['SINIESTRO']]

# %%
X_test19, y_test19 = test100[[#'Unnamed: 0', 
                 #'X', 
                 #'Y', 
                 'attraction', 
                 'bank', 
                 'bar', 
                 'cetram', 
                 'cinema', 
                 'college', 
                 'crossing', 
                 'cruce_peligroso', 
                 'hospital',  
                 'hotel', 
                 'interseccion', 
                 'kindergarten', 
                 'mall', 
                 'metro', 
                 'metrobus', 
                 'mini_roundabout', 
                 'museum', 
                 'nightclub', 
                 'park', 
                 'pub', 
                 'restaurant', 
                 'rtp', 
                 'school', 
                 'speed_camera', 
                 'supermarket', 
                 'theatre', 
                 'traffic_signals', 
                 'trolebus', 
                 'turning_circle', 
                 'university',
                 
                 'bar_300',
                 'crossing_300',
                 'hospital_300',
                 'hotel_300',
                 'metro_300',
                 'nightclub_300',
                 'restaurant_300', 
                 'rtp_300',
                 'school_300',
                 'speed_camera_300',
                 'traffic_signals_300',
                 
                 'ACC_C_LESION_100',
                 'ACC_FATAL_100', 
                 'ACC_PRENSADO_100', 
                 'ACC_S_LESION_100',
                 'ATROPELLADO_100', 
                 'ATROPELLADO_FATAL_100',
                 'FERROVIARIO_100',
                 'MOTOCICLISTA_100',
                 'OTROS_100',
                 'PER_ATRAPADO_DESBARRANCADO_100',
                 'VEH_ATRAPADO_100',
                 'VEH_DESBARRANCADO_100', 
                 'VOLCADURA_100',

                 'ACC_C_LESION_200', 
                 'ACC_FATAL_200',
                 'ACC_PRENSADO_200', 
                 'ACC_S_LESION_200', 
                 'ATROPELLADO_200',
                 'ATROPELLADO_FATAL_200', 
                 'FERROVIARIO_200', 
                 'MOTOCICLISTA_200', 
                 'OTROS_200', 
                 'PER_ATRAPADO_DESBARRANCADO_200', 
                 'VEH_ATRAPADO_200', 
                 'VEH_DESBARRANCADO_200',
                 'VOLCADURA_200']],test100[['SINIESTRO']]

# %% [markdown]
# ## Decision Tree Classifier

# %% [markdown]
# ### Entrenamos el modelo DT parámetros default con datos acumulados 2014-2018

# %%
#Usando validación cruzada con DT
instancia_kfold = KFold(n_splits = 10)
acc = cross_val_score(tree.DecisionTreeClassifier(random_state = 42), X,y, cv = instancia_kfold)
roc = cross_val_score(tree.DecisionTreeClassifier(random_state = 42), X,y, scoring = 'roc_auc',cv = instancia_kfold)
matt = cross_val_score(tree.DecisionTreeClassifier(random_state = 42), X,y, scoring = make_scorer(matthews_corrcoef),cv = instancia_kfold)
cohen = cross_val_score(tree.DecisionTreeClassifier(random_state = 42), X,y, scoring = make_scorer(cohen_kappa_score),cv = instancia_kfold)

print("acc",acc)
print("roc",roc)
print("matt",matt)
print("kappa",cohen)
# Out:
# acc [0.80774521 0.75695694 0.81282404 0.72373294 0.70130145 0.70288858
#  0.85133848 0.78880542 0.67643636 0.72986986]
# roc [0.71424444 0.72900209 0.72209852 0.72132827 0.69902307 0.70020847
#  0.76660638 0.7347668  0.67634082 0.72140565]
# matt [0.42055145 0.46216651 0.43583412 0.44483863 0.39940616 0.3992809
#  0.53120583 0.46223307 0.35335908 0.44613468]
# kappa [0.42053347 0.4617954  0.43583356 0.44463281 0.39940355 0.39885378
#  0.53104813 0.46189424 0.35305517 0.44605519]

# %% [markdown]
# ### Corremos predicción para clasificación de hexágonos para datos 2019

# %%
clf = tree.DecisionTreeClassifier(random_state = 42)
   
clf = clf.fit(X, y)

y_pred = clf.predict(X_test19)
print(accuracy_score(y_test19, y_pred))
print("Kappa: ",cohen_kappa_score(y_test19, y_pred))
print("ROC_AUC_CURVE: ",roc_auc_score(y_test19, y_pred.round()))
print("MCC: ", matthews_corrcoef(y_test19, y_pred))
print(confusion_matrix(y_test19, y_pred))
# Out:
# 0.7702359538673156
# Kappa:  0.3309129292385168
# ROC_AUC_CURVE:  0.6689566815525749
# MCC:  0.33113001546946724
# [[62850 11445]
#  [10270  9945]]

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# ### Entrenamos el modelo RF con parámetros default y datos acumulados 2014-2018

# %%
instancia_kfold = KFold(n_splits = 10)
rf_acc = cross_val_score(RandomForestClassifier(random_state = 42), X, y, cv = instancia_kfold)
rf_roc = cross_val_score(RandomForestClassifier(random_state = 42), X, y, scoring = 'roc_auc', cv = instancia_kfold)
rf_matt = cross_val_score(RandomForestClassifier(random_state = 42), X, y, scoring = make_scorer(matthews_corrcoef), cv = instancia_kfold)
rf_cohen = cross_val_score(RandomForestClassifier(random_state = 42), X, y, scoring = make_scorer(cohen_kappa_score), cv = instancia_kfold)

print("acc",rf_acc)
print("roc",rf_roc)
print("matt",rf_matt)
print("kappa",rf_cohen)
# Out:
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %% [markdown]
# ### Corremos predicción para clasificación de hexágonos para datos 2019

# %%
rf_clas = RandomForestClassifier(random_state = 42)

rf_clas.fit(X, y)

y_pred = rf_clas.predict(X_test19)
print(accuracy_score(y_test19, y_pred))
print("Kappa: ",cohen_kappa_score(y_test19, y_pred))
print("ROC_AUC_CURVE: ",roc_auc_score(y_test19, y_pred.round()))
print("MCC: ", matthews_corrcoef(y_test19, y_pred))
print(confusion_matrix(y_test19, y_pred))
# Out:
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/envs/poder/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.8221140620040207
# Kappa:  0.4048013463930734
# ROC_AUC_CURVE:  0.6798803933826847
# MCC:  0.41485257442945506
# [[68979  5316]
#  [11496  8719]]

# %% [markdown]
# ## ADABOOST Classifier

# %% [markdown]
# ### Entrenamos el modelo ADA con parámetros default y datos acumulados 2014-2018

# %%
instancia_kfold = KFold(n_splits = 10)
dt = DecisionTreeClassifier(random_state = 42)
adb_acc = cross_val_score(AdaBoostClassifier(base_estimator = dt), X, y, scoring = 'accuracy', cv = instancia_kfold)
adb_roc = cross_val_score(AdaBoostClassifier(base_estimator = dt), X, y, scoring = 'roc_auc', cv = instancia_kfold)
adb_matt = cross_val_score(AdaBoostClassifier(base_estimator = dt), X, y, scoring = make_scorer(matthews_corrcoef), cv = instancia_kfold)
adb_cohen = cross_val_score(AdaBoostClassifier(base_estimator = dt), X, y, scoring = make_scorer(cohen_kappa_score), cv = instancia_kfold)

print("acc",adb_acc)
print("roc",adb_roc)
print("matt",adb_matt)
print("kappa",adb_cohen)
# Out:
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ### Corremos predicción para clasificación de hexágonos para datos 2019

# %%
dt = DecisionTreeClassifier(max_depth = 1, random_state = 42)
adb_clf = AdaBoostClassifier(base_estimator = dt)

adb_clf.fit(X, y)

y_pred = adb_clf.predict(X_test19)
print(accuracy_score(y_test19, y_pred))
print("Kappa: ",cohen_kappa_score(y_test19, y_pred))
print("ROC_AUC_CURVE: ",roc_auc_score(y_test19, y_pred.round()))
print("MCC: ", matthews_corrcoef(y_test19, y_pred))
print(confusion_matrix(y_test19, y_pred))
# Out:
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8393080097344197
# Kappa:  0.5237761700566446
# ROC_AUC_CURVE:  0.7627792352075208
# MCC:  0.5237853688116046
# [[66607  7688]
#  [ 7499 12716]]

# %% [markdown]
# ## GBM Classifier

# %% [markdown]
# ### Entrenamos el modelo GBM con parámetros default y datos acumulados 2014-2018

# %%
instancia_kfold = KFold(n_splits = 10)
gbc_acc = cross_val_score(GradientBoostingClassifier(random_state=42), X, y, scoring = 'accuracy',cv = instancia_kfold)
gbc_roc = cross_val_score(GradientBoostingClassifier(random_state=42), X, y, scoring = 'roc_auc',cv = instancia_kfold)
gbc_matt = cross_val_score(GradientBoostingClassifier(random_state=42), X, y, scoring = make_scorer(matthews_corrcoef),cv = instancia_kfold)
gbc_cohen = cross_val_score(GradientBoostingClassifier(random_state=42), X, y, scoring = make_scorer(cohen_kappa_score),cv = instancia_kfold)

print("acc",gbc_acc)
print("roc",gbc_roc)
print("matt",gbc_matt)
print("kappa",gbc_cohen)
# Out:
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/envs/poder/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ### Corremos predicción para clasificación de hexágonos para datos 2019

# %%
gbc_clf = GradientBoostingClassifier(random_state=42)

gbc_clf.fit(X, y)

y_pred = gbc_clf.predict(X_test19)
print(accuracy_score(y_test19, y_pred))
print("Kappa: ",cohen_kappa_score(y_test19, y_pred))
print("ROC_AUC_CURVE: ",roc_auc_score(y_test19, y_pred.round()))
print("MCC: ", matthews_corrcoef(y_test19, y_pred))
print(confusion_matrix(y_test19, y_pred))
